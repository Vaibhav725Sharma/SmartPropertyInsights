# %% [markdown]
# ### Step 1: Install Necessary Packages

# %% [markdown]
# Install Selenium and the WebDriver Manager for easy driver management.
#
# pip install selenium
# pip install webdriver-manager
#
# Install Additional Libraries
# pip install fake-useragent
#
# fake_useragent for generating random User-Agent headers (or you can create a list of User-Agents).

# %%
#from selenium import webdriver
#from selenium.webdriver.chrome.service import Service
#from selenium.webdriver.chrome.options import Options
#from webdriver_manager.chrome import ChromeDriverManager
#from fake_useragent import UserAgent
#import time
#import random
#import os

# %% [markdown]
# #### Step 2:Set Up Headless Selenium with Random User-Agent and Delays

# %% [markdown]
# Import Libraries:

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from fake_useragent import UserAgent
import time
import random
import os

# %% [markdown]
# Configure Headless Mode and Set Up Random User-Agent

# %% [markdown]
# 1. Headless Mode: Running Chrome in headless mode lets you scrape without opening a browser window, making it faster and more efficient.
# 2. Randomized User-Agent: Randomizing the User-Agent string for each session helps mimic different users and makes detection harder.

# %%
def get_random_user_agent():
    ua = UserAgent()  # Initializes fake_useragent to generate random User-Agents
    return ua.random  # Returns a random User-Agent string

def setup_browser_options():
    chrome_options = Options()
    
    # Enable headless mode
    chrome_options.add_argument("--headless")  # Run browser in headless mode
    chrome_options.add_argument("--disable-gpu")  # Disable GPU (helps with headless performance)
    chrome_options.add_argument("--no-sandbox")  # Bypass OS security model, for Docker compatibility
    
    # Randomize User-Agent
    user_agent = get_random_user_agent()
    chrome_options.add_argument(f"user-agent={user_agent}")
    
    # Optional: Disable automation flags for better disguise
    chrome_options.add_argument("--disable-blink-features=AutomationControlled")
    
    return chrome_options

# %% [markdown]
# #### Step 3: Implement Randomized Delay

# %% [markdown]
# Introducing small, random delays between requests can make your actions appear more like real user behavior, helping to avoid detection.

# %%
def add_random_delay():
    delay = random.uniform(2, 5)  # Delay between 2 and 5 seconds
    time.sleep(delay)

# %% [markdown]
# Step 4: Putting It All Together

# %%
def fetch_and_save_to_file(url, path):
    # Set up Chrome with customized options
    chrome_options = setup_browser_options()
    
    # Initialize Chrome WebDriver with options
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    
    # Create the directory if it doesn't exist
    directory = os.path.dirname(path)
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    try:
        # Open the target URL
        driver.get(url)
        
        # Add random delay
        add_random_delay()
        
        # Save the HTML source to a file
        with open(path, "w", encoding="utf-8") as f:
            f.write(driver.page_source)
        print("HTML content saved successfully!")
    
    finally:
        # Close the browser session
        driver.quit()

# Usage example
url = "https://www.99acres.com/search/property/buy/gurgaon?city=8&preference=S&area_unit=1&budget_min=0&res_com=R&isPreLeased=N"
path = "Scraped Html/99acres_2.html"
fetch_and_save_to_file(url, path)
# Out:
# HTML content saved successfully!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from fake_useragent import UserAgent
import time
import random
import os

def get_random_user_agent():
    ua = UserAgent()  # Initializes fake_useragent to generate random User-Agents
    return ua.random  # Returns a random User-Agent string

def setup_browser_options():
    chrome_options = Options()
    
    # Enable headless mode
    chrome_options.add_argument("--headless")  # Run browser in headless mode
    chrome_options.add_argument("--disable-gpu")  # Disable GPU (helps with headless performance)
    chrome_options.add_argument("--no-sandbox")  # Bypass OS security model, for Docker compatibility
    
    # Randomize User-Agent
    user_agent = get_random_user_agent()
    chrome_options.add_argument(f"user-agent={user_agent}")
    
    # Optional: Disable automation flags for better disguise
    chrome_options.add_argument("--disable-blink-features=AutomationControlled")
    
    return chrome_options

def add_random_delay():
    delay = random.uniform(2, 5)  # Delay between 2 and 5 seconds
    time.sleep(delay)

def fetch_and_save_to_file(url, path):
    # Set up Chrome with customized options
    chrome_options = setup_browser_options()
    
    # Initialize Chrome WebDriver with options
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    
    # Create the directory if it doesn't exist
    directory = os.path.dirname(path)
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    try:
        # Open the target URL
        driver.get(url)
        
        # Add random delay
        add_random_delay()
        
        # Save the HTML source to a file
        with open(path, "w", encoding="utf-8") as f:
            f.write(driver.page_source)
        print(f"HTML content saved to {path}")
    
    finally:
        # Close the browser session
        driver.quit()

def scrape_multiple_pages(base_url, total_pages, path_prefix):
    # Start scraping from page 225
    for page_num in range(1, total_pages + 1):
        # Construct the URL with page number (assuming the URL structure changes with the page number)
        url = f"{base_url}&page={page_num}"
        
        # Generate the path for saving the HTML file
        path = f"{path_prefix}/page_{page_num}.html"
        
        try:
            # Fetch and save the HTML content for the page
            fetch_and_save_to_file(url, path)
        except Exception as e:
            print(f"Error scraping page {page_num}: {e}")
            break  # Stop on error, and you can resume later from where it stopped


# Usage example: scraping 1674 pages
base_url = "https://www.99acres.com/search/property/buy/gurgaon?city=8&preference=S&area_unit=1&budget_min=0&res_com=R&isPreLeased=N"
path_prefix = "Scraped Html"
total_pages = 1680

scrape_multiple_pages(base_url, total_pages, path_prefix)
# Out:
# HTML content saved to 001_Scraped Html/page_1.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from fake_useragent import UserAgent
import time
import random
import os

def get_random_user_agent():
    ua = UserAgent()  # Initializes fake_useragent to generate random User-Agents
    user_agent = ua.random  # Returns a random User-Agent string
    print("Using User-Agent:", user_agent)  # Debug print
    return user_agent

def setup_browser_options():
    chrome_options = Options()
    
    # Enable headless mode (comment out for debugging with GUI)
    # chrome_options.add_argument("--headless")  
    
    # Disable GPU and sandbox for compatibility
    chrome_options.add_argument("--disable-gpu")  
    chrome_options.add_argument("--no-sandbox")  
    
    # Randomize User-Agent
    user_agent = get_random_user_agent()
    chrome_options.add_argument(f"user-agent={user_agent}")
    
    # Optional: Disable automation flags for better disguise
    chrome_options.add_argument("--disable-blink-features=AutomationControlled")
    
    return chrome_options

def add_random_delay():
    delay = random.uniform(2, 5)  # Delay between 2 and 5 seconds
    print(f"Sleeping for {delay:.2f} seconds")  # Debug print
    time.sleep(delay)

def fetch_and_save_to_file(url, path):
    # Set up Chrome with customized options
    chrome_options = setup_browser_options()
    
    # Initialize Chrome WebDriver with options
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    print("ChromeDriver initialized")  # Debug print
    
    # Create the directory if it doesn't exist
    directory = os.path.dirname(path)
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Directory created at {directory}")  # Debug print
    
    try:
        # Open the target URL
        print(f"Opening URL: {url}")  # Debug print
        driver.get(url)
        
        # Add random delay
        add_random_delay()
        
        # Save the HTML source to a file
        with open(path, "w", encoding="utf-8") as f:
            f.write(driver.page_source)
        print(f"HTML content saved to {path}")  # Success message
    
    except Exception as e:
        print(f"Error fetching URL {url}: {e}")  # Debug print on error
    
    finally:
        # Close the browser session
        driver.quit()
        print("Browser session closed")  # Debug print

def scrape_multiple_pages(base_url, total_pages, path_prefix):
    # Start scraping from page 1639
    for page_num in range(1681, total_pages + 1):
        # Construct the URL with page number
        url = f"{base_url}&page={page_num}"
        
        # Generate the path for saving the HTML file
        path = f"{path_prefix}/page_2_{page_num}.html"
        
        print(f"Scraping page {page_num}")  # Debug print for each page
        
        try:
            # Fetch and save the HTML content for the page
            fetch_and_save_to_file(url, path)
        
        except Exception as e:
            print(f"Error scraping page {page_num}: {e}")  # Debug print on error
            break  # Stop on error; can resume later from where it stopped

# Usage example: scraping 1680 pages
base_url = "https://www.99acres.com/search/property/buy/gurgaon?city=8&preference=S&area_unit=1&budget_min=0&res_com=R&isPreLeased=N"
path_prefix = "Scraped Html"
total_pages = 1682

scrape_multiple_pages(base_url, total_pages, path_prefix)
# Out:
# Scraping page 1681
# Using User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0 Agency/98.8.8188.80
# ChromeDriver initialized
# Opening URL: https://www.99acres.com/search/property/buy/gurgaon?city=8&preference=S&area_unit=1&budget_min=0&res_com=R&isPreLeased=N&page=1681
# Sleeping for 2.93 seconds

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from fake_useragent import UserAgent
import time
import random
import os

def get_random_user_agent():
    ua = UserAgent()  # Initializes fake_useragent to generate random User-Agents
    return ua.random  # Returns a random User-Agent string

def setup_browser_options():
    chrome_options = Options()
    
    # Enable headless mode
    chrome_options.add_argument("--headless")  # Run browser in headless mode
    chrome_options.add_argument("--disable-gpu")  # Disable GPU (helps with headless performance)
    chrome_options.add_argument("--no-sandbox")  # Bypass OS security model, for Docker compatibility
    
    # Randomize User-Agent
    user_agent = get_random_user_agent()
    chrome_options.add_argument(f"user-agent={user_agent}")
    
    # Optional: Disable automation flags for better disguise
    chrome_options.add_argument("--disable-blink-features=AutomationControlled")
    
    return chrome_options

def add_random_delay():
    delay = random.uniform(2, 5)  # Delay between 2 and 5 seconds
    time.sleep(delay)

def fetch_and_save_to_file(url, path):
    # Set up Chrome with customized options
    chrome_options = setup_browser_options()
    
    # Initialize Chrome WebDriver with options
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    
    # Create the directory if it doesn't exist
    directory = os.path.dirname(path)
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    try:
        # Open the target URL
        driver.get(url)
        
        # Add random delay
        add_random_delay()
        
        # Save the HTML source to a file
        with open(path, "w", encoding="utf-8") as f:
            f.write(driver.page_source)
        print(f"HTML content saved to {path}")
    
    finally:
        # Close the browser session
        driver.quit()

def scrape_specific_pages(base_url, page_numbers, path_prefix):
    for page_num in page_numbers:
        # Construct the URL with page number
        url = f"{base_url}&page={page_num}"
        
        # Generate the path for saving the HTML file
        path = f"{path_prefix}/page_2_{page_num}.html"
        
        try:
            # Fetch and save the HTML content for the page
            fetch_and_save_to_file(url, path)
        except Exception as e:
            print(f"Error scraping page {page_num}: {e}")
            continue  # Skip to the next page if an error occurs

# Scraping without changing name 
#


#Scraping after Changing name
#259, 26, 260, 262, 266, 267, 269, 270, 272, 275, 276, 277, 278, 279, 28, 280, 281, 285, 286, 287, 288, 289, 290, 292, 297, 30, 302, 304, 305, 307, 31, 310, 313, 314, 317, 32, 324, 325, 329, 330, 331, 333, 334, 335, 338, 339, 34, 341, 342, 345, 347, 35, 350, 353, 356, 358, 36, 361, 363, 365, 366, 367, 369, 37, 370, 371, 372, 375, 377, 378, 38, 380, 381, 382, 383, 387, 39, 393, 397, 399, 402, 403, 404, 405, 407, 41, 412, 413, 415, 416, 417, 418, 420, 421, 423, 424, 425, 427, 431, 435, 436, 437, 439, 440, 442, 443, 444, 445, 446, 447, 448, 449, 451, 454, 455, 456, 457, 458, 459, 46, 462, 463, 465, 466, 468, 471, 473, 474, 476, 48, 485, 486, 489, 49, 490, 492, 495, 498, 50, 501, 504, 506, 507, 509, 51, 510, 511, 513, 515, 516, 519, 52, 522, 526, 527, 528, 530, 531, 534, 535, 536, 54, 540, 542, 543, 546, 548, 550, 551, 552, 554, 557, 558, 559, 56, 561, 562, 563, 564, 566, 567, 569, 570, 571, 573, 574, 576, 577, 579, 58, 580, 582, 584, 585, 586, 587, 589, 59, 590, 594, 595, 597, 599, 60, 601, 602, 603, 604, 607, 608, 61, 610, 612, 614, 615, 616, 617, 618, 619, 62, 621, 622, 623, 624, 625, 626, 628, 63, 631, 632, 633, 635, 637, 639, 64, 640, 641, 644, 646, 647, 648, 649, 65, 652, 653, 654, 655, 656, 657, 658, 659, 66, 660, 661, 662, 663, 664, 667, 668, 67, 670, 671, 672, 674, 675, 676, 678, 679, 68, 680, 681, 683, 685, 686, 687, 689, 69, 690, 692, 693, 695, 698, 699, 70, 702, 703, 704, 705, 706, 708, 71, 711, 712, 713, 715, 716, 718, 72, 721, 724, 726, 728, 730, 731, 733, 734, 735, 736, 738, 739, 74, 740, 741, 742, 744, 746, 748, 75, 750, 752, 753, 754, 756, 758, 76, 761, 762, 763, 765, 766, 767, 769, 77, 771, 772, 773, 775, 777, 779, 78, 780, 783, 784, 785, 787, 788, 789, 790, 791, 793, 794, 795, 796, 797, 798, 799, 80, 800, 801, 802, 803, 805, 806, 807, 809, 81, 811, 812, 813, 814, 815, 817, 818, 82, 821, 822, 823, 824, 826, 828, 83, 831, 832, 833, 834, 836, 837, 839, 84, 840, 841, 842, 843, 844, 846, 848, 85, 851, 852, 854, 855, 856, 857, 858, 86, 860, 861, 862, 863, 864, 866, 868, 87, 871, 872, 873, 874, 875, 876, 877, 878, 879, 88, 880, 882, 884, 885, 886, 887, 888, 889, 89, 890, 891, 892, 894, 896, 897, 898, 9, 90,903,905,906,907, 91, 910, 913, 914, 915, 92, 922, 924 ,927 ,928, 93, 930, 933, 934, 935, 936, 938, 939, 94, 941, 943, 945, 946, 947, 948, 951, 952, 954, 955, 959, 961, 962, 963, 966 ,967,968, 97, 970, 971, 972, 973, 975, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 996,997, 998, 999


# Array of page numbers to scrape
page_numbers = [10, 100, 1000, 1002, 1004, 1005, 1006, 101, 1010, 1011, 1012, 1014, 1015, 1019, 102, 1020, 1026, 1027, 1030, 1031, 1032, 1033, 1038, 104, 1041, 1042, 1044, 1045, 1046, 1048, 1049, 105, 1051, 1052, 1053, 1057, 1058, 1059, 106, 1062, 1064, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1075, 1076, 1077, 1080, 1082, 1084, 1088, 1089, 109, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1098, 11, 110, 1100, 1104, 1105, 1109, 1110, 1113, 1114, 1116, 112, 1121, 1122, 1123, 1125, 1126, 1127, 113, 1130, 1131, 1132, 1136, 1137, 114, 1141, 1144, 1146, 1147, 1148, 1149, 1151, 1152, 1153, 1154, 1157, 1158, 1159, 1160, 1165, 117, 1171, 1173, 1175, 1176, 1177, 1179, 1181, 1183, 1184, 1185, 1186, 1189, 119, 1190, 1191, 1192, 1193, 1196, 1197, 12, 1200, 1201, 1202, 1203, 1204, 1207, 121, 1212, 1213, 1214, 1218, 1225, 1227, 1228, 1230, 1231, 1232, 1235, 1236, 1237, 1238, 1239, 124, 1243, 1245, 1246, 1248, 1249, 125, 1251, 1252, 1254, 1258, 1259, 126, 1261, 1263, 1264, 1265, 127, 1270, 1272, 1274, 1276, 1277, 1278, 1279, 128, 1283, 1284, 1287, 1288, 1289, 129, 1291, 1292, 1293, 1295, 1296, 1297, 1299, 130, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1311, 1312, 1313, 1315, 1316, 1317, 1320, 1324, 1325, 1328, 1329, 133, 1331, 134, 135, 1367, 1368, 1370, 1371, 1372, 1374, 1375, 1376, 1377, 1379, 1380, 1382, 1386, 1387, 1388, 1390, 1391, 1392, 1395, 1396, 1397, 1398, 14, 1402, 1406, 1407, 1408, 1409, 141, 1410, 1413, 1414, 1415, 1417, 1419, 142, 1421, 1422, 1423, 1425, 1427, 1428, 1430, 1431, 1432, 1435, 1436, 1437, 1438, 1441, 1447, 1449, 145, 1454, 1456, 1459, 1461, 1466, 1468, 1469, 1473, 1474, 1476, 1477, 1478, 1479, 1480, 1483, 1484, 1485, 1486, 1487, 1488, 149, 1490, 1491, 1492, 1493, 1496, 1497, 1498, 1499, 15, 1500, 1501, 1502, 1509, 151, 1511, 1513, 1515, 1516, 1518, 1519, 152, 1522, 1525, 1527, 1528, 1529, 1530, 1532, 1533, 1534, 1535, 1536, 1537, 1539, 1542, 1543, 1545, 1548, 155, 1553, 1554, 1556, 1558, 156, 1561, 1562, 1564, 157, 1570, 1572, 1574, 1577, 1578, 1579, 158, 1580, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1593, 1594, 1595, 1598, 16, 160, 1601, 1602, 1603, 1604, 1606, 1607, 1611, 1612, 1613, 1618, 162, 1621, 1623, 1624, 1625, 1627, 1628, 1629, 1631, 1632, 1633, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1644, 1646, 165, 1653, 1654, 1655, 1657, 1659, 166, 1660, 1661, 1662, 1663, 1667, 1669, 1671, 1673, 1676, 168, 1680, 174, 175, 176, 177, 178, 18, 181, 183, 184, 185, 188, 19, 196, 203, 204, 21, 210, 211, 214, 215, 218, 219, 22, 220, 221, 225, 227, 228, 23, 230, 232, 235, 245, 246, 247, 248, 249, 251, 254, 255]

  # Replace with the specific array of pages you need

# Base URL and path prefix
base_url = "https://www.99acres.com/search/property/buy/gurgaon?city=8&preference=S&area_unit=1&budget_min=0&res_com=R&isPreLeased=N"
path_prefix = "Scraped Html"

# Run the scraper for only the specified pages
scrape_specific_pages(base_url, page_numbers, path_prefix)
# Out:
# HTML content saved to Scraped Html/page_2_10.html
# HTML content saved to Scraped Html/page_2_100.html
# HTML content saved to Scraped Html/page_2_1000.html
# HTML content saved to Scraped Html/page_2_1002.html
# HTML content saved to Scraped Html/page_2_1004.html
# HTML content saved to Scraped Html/page_2_1005.html
# HTML content saved to Scraped Html/page_2_1006.html
# HTML content saved to Scraped Html/page_2_101.html
# HTML content saved to Scraped Html/page_2_1010.html
# HTML content saved to Scraped Html/page_2_1011.html
# HTML content saved to Scraped Html/page_2_1012.html
# HTML content saved to Scraped Html/page_2_1014.html
# HTML content saved to Scraped Html/page_2_1015.html
# HTML content saved to Scraped Html/page_2_1019.html
# HTML content saved to Scraped Html/page_2_102.html
# HTML content saved to Scraped Html/page_2_1020.html
# HTML content saved to Scraped Html/page_2_1026.html
# HTML content saved to Scraped Html/page_2_1027.html
# HTML content saved to Scraped Html/page_2_1030.html
# HTML content saved to Scraped Html/page_2_1031.html
# HTML content saved to Scraped Html/page_2_1032.html
# HTML content saved to Scraped Html/page_2_1033.html
# HTML content saved to Scraped Html/page_2_1038.html
# HTML content saved to Scraped Html/page_2_104.html
# HTML content saved to Scraped Html/page_2_1041.html
# HTML content saved to Scraped Html/page_2_1042.html
# HTML content saved to Scraped Html/page_2_1044.html
# HTML content saved to Scraped Html/page_2_1045.html
# HTML content saved to Scraped Html/page_2_1046.html
# HTML content saved to Scraped Html/page_2_1048.html
# HTML content saved to Scraped Html/page_2_1049.html
# HTML content saved to Scraped Html/page_2_105.html
# HTML content saved to Scraped Html/page_2_1051.html
# HTML content saved to Scraped Html/page_2_1052.html
# HTML content saved to Scraped Html/page_2_1053.html
# HTML content saved to Scraped Html/page_2_1057.html
# HTML content saved to Scraped Html/page_2_1058.html
# HTML content saved to Scraped Html/page_2_1059.html
# HTML content saved to Scraped Html/page_2_106.html
# HTML content saved to Scraped Html/page_2_1062.html
# HTML content saved to Scraped Html/page_2_1064.html
# HTML content saved to Scraped Html/page_2_1066.html
# HTML content saved to Scraped Html/page_2_1067.html
# HTML content saved to Scraped Html/page_2_1068.html
# HTML content saved to Scraped Html/page_2_1069.html
# HTML content saved to Scraped Html/page_2_1070.html
# HTML content saved to Scraped Html/page_2_1071.html
# HTML content saved to Scraped Html/page_2_1072.html
# HTML content saved to Scraped Html/page_2_1075.html
# HTML content saved to Scraped Html/page_2_1076.html
# HTML content saved to Scraped Html/page_2_1077.html
# HTML content saved to Scraped Html/page_2_1080.html
# HTML content saved to Scraped Html/page_2_1082.html
# HTML content saved to Scraped Html/page_2_1084.html
# HTML content saved to Scraped Html/page_2_1088.html
# HTML content saved to Scraped Html/page_2_1089.html
# HTML content saved to Scraped Html/page_2_109.html
# HTML content saved to Scraped Html/page_2_1090.html
# HTML content saved to Scraped Html/page_2_1091.html
# HTML content saved to Scraped Html/page_2_1092.html
# HTML content saved to Scraped Html/page_2_1093.html
# HTML content saved to Scraped Html/page_2_1094.html
# HTML content saved to Scraped Html/page_2_1095.html
# HTML content saved to Scraped Html/page_2_1096.html
# HTML content saved to Scraped Html/page_2_1098.html
# HTML content saved to Scraped Html/page_2_11.html
# HTML content saved to Scraped Html/page_2_110.html
# HTML content saved to Scraped Html/page_2_1100.html
# HTML content saved to Scraped Html/page_2_1104.html
# HTML content saved to Scraped Html/page_2_1105.html
# HTML content saved to Scraped Html/page_2_1109.html
# HTML content saved to Scraped Html/page_2_1110.html
# HTML content saved to Scraped Html/page_2_1113.html
# HTML content saved to Scraped Html/page_2_1114.html
# HTML content saved to Scraped Html/page_2_1116.html
# HTML content saved to Scraped Html/page_2_112.html
# HTML content saved to Scraped Html/page_2_1121.html
# HTML content saved to Scraped Html/page_2_1122.html
# HTML content saved to Scraped Html/page_2_1123.html
# HTML content saved to Scraped Html/page_2_1125.html
# HTML content saved to Scraped Html/page_2_1126.html
# HTML content saved to Scraped Html/page_2_1127.html
# HTML content saved to Scraped Html/page_2_113.html
# HTML content saved to Scraped Html/page_2_1130.html
# HTML content saved to Scraped Html/page_2_1131.html
# HTML content saved to Scraped Html/page_2_1132.html
# HTML content saved to Scraped Html/page_2_1136.html
# HTML content saved to Scraped Html/page_2_1137.html
# HTML content saved to Scraped Html/page_2_114.html
# HTML content saved to Scraped Html/page_2_1141.html
# HTML content saved to Scraped Html/page_2_1144.html
# HTML content saved to Scraped Html/page_2_1146.html
# HTML content saved to Scraped Html/page_2_1147.html
# HTML content saved to Scraped Html/page_2_1148.html
# HTML content saved to Scraped Html/page_2_1149.html
# HTML content saved to Scraped Html/page_2_1151.html
# HTML content saved to Scraped Html/page_2_1152.html
# HTML content saved to Scraped Html/page_2_1153.html
# HTML content saved to Scraped Html/page_2_1154.html
# HTML content saved to Scraped Html/page_2_1157.html
# HTML content saved to Scraped Html/page_2_1158.html
# HTML content saved to Scraped Html/page_2_1159.html
# HTML content saved to Scraped Html/page_2_1160.html
# HTML content saved to Scraped Html/page_2_1165.html
# HTML content saved to Scraped Html/page_2_117.html
# HTML content saved to Scraped Html/page_2_1171.html
# HTML content saved to Scraped Html/page_2_1173.html
# HTML content saved to Scraped Html/page_2_1175.html
# HTML content saved to Scraped Html/page_2_1176.html
# HTML content saved to Scraped Html/page_2_1177.html
# HTML content saved to Scraped Html/page_2_1179.html
# HTML content saved to Scraped Html/page_2_1181.html
# HTML content saved to Scraped Html/page_2_1183.html
# HTML content saved to Scraped Html/page_2_1184.html
# HTML content saved to Scraped Html/page_2_1185.html
# HTML content saved to Scraped Html/page_2_1186.html
# HTML content saved to Scraped Html/page_2_1189.html
# HTML content saved to Scraped Html/page_2_119.html
# HTML content saved to Scraped Html/page_2_1190.html
# HTML content saved to Scraped Html/page_2_1191.html
# HTML content saved to Scraped Html/page_2_1192.html
# HTML content saved to Scraped Html/page_2_1193.html
# HTML content saved to Scraped Html/page_2_1196.html
# HTML content saved to Scraped Html/page_2_1197.html
# HTML content saved to Scraped Html/page_2_12.html
# HTML content saved to Scraped Html/page_2_1200.html
# HTML content saved to Scraped Html/page_2_1201.html
# HTML content saved to Scraped Html/page_2_1202.html
# HTML content saved to Scraped Html/page_2_1203.html
# HTML content saved to Scraped Html/page_2_1204.html
# HTML content saved to Scraped Html/page_2_1207.html
# HTML content saved to Scraped Html/page_2_121.html
# HTML content saved to Scraped Html/page_2_1212.html
# HTML content saved to Scraped Html/page_2_1213.html
# HTML content saved to Scraped Html/page_2_1214.html
# HTML content saved to Scraped Html/page_2_1218.html
# HTML content saved to Scraped Html/page_2_1225.html
# HTML content saved to Scraped Html/page_2_1227.html
# HTML content saved to Scraped Html/page_2_1228.html
# HTML content saved to Scraped Html/page_2_1230.html
# HTML content saved to Scraped Html/page_2_1231.html
# HTML content saved to Scraped Html/page_2_1232.html
# HTML content saved to Scraped Html/page_2_1235.html
# HTML content saved to Scraped Html/page_2_1236.html
# HTML content saved to Scraped Html/page_2_1237.html
# HTML content saved to Scraped Html/page_2_1238.html
# HTML content saved to Scraped Html/page_2_1239.html
# HTML content saved to Scraped Html/page_2_124.html
# HTML content saved to Scraped Html/page_2_1243.html
# HTML content saved to Scraped Html/page_2_1245.html
# HTML content saved to Scraped Html/page_2_1246.html
# HTML content saved to Scraped Html/page_2_1248.html
# HTML content saved to Scraped Html/page_2_1249.html
# HTML content saved to Scraped Html/page_2_125.html
# HTML content saved to Scraped Html/page_2_1251.html
# HTML content saved to Scraped Html/page_2_1252.html
# HTML content saved to Scraped Html/page_2_1254.html
# HTML content saved to Scraped Html/page_2_1258.html
# HTML content saved to Scraped Html/page_2_1259.html
# HTML content saved to Scraped Html/page_2_126.html
# HTML content saved to Scraped Html/page_2_1261.html
# HTML content saved to Scraped Html/page_2_1263.html
# HTML content saved to Scraped Html/page_2_1264.html
# HTML content saved to Scraped Html/page_2_1265.html
# HTML content saved to Scraped Html/page_2_127.html
# HTML content saved to Scraped Html/page_2_1270.html
# HTML content saved to Scraped Html/page_2_1272.html
# HTML content saved to Scraped Html/page_2_1274.html
# HTML content saved to Scraped Html/page_2_1276.html
# HTML content saved to Scraped Html/page_2_1277.html
# HTML content saved to Scraped Html/page_2_1278.html
# HTML content saved to Scraped Html/page_2_1279.html
# HTML content saved to Scraped Html/page_2_128.html
# HTML content saved to Scraped Html/page_2_1283.html
# HTML content saved to Scraped Html/page_2_1284.html
# HTML content saved to Scraped Html/page_2_1287.html
# HTML content saved to Scraped Html/page_2_1288.html
# HTML content saved to Scraped Html/page_2_1289.html
# HTML content saved to Scraped Html/page_2_129.html
# HTML content saved to Scraped Html/page_2_1291.html
# HTML content saved to Scraped Html/page_2_1292.html
# HTML content saved to Scraped Html/page_2_1293.html
# HTML content saved to Scraped Html/page_2_1295.html
# HTML content saved to Scraped Html/page_2_1296.html
# HTML content saved to Scraped Html/page_2_1297.html
# HTML content saved to Scraped Html/page_2_1299.html
# HTML content saved to Scraped Html/page_2_130.html
# HTML content saved to Scraped Html/page_2_1302.html
# HTML content saved to Scraped Html/page_2_1303.html
# HTML content saved to Scraped Html/page_2_1304.html
# HTML content saved to Scraped Html/page_2_1305.html
# HTML content saved to Scraped Html/page_2_1306.html
# HTML content saved to Scraped Html/page_2_1307.html
# HTML content saved to Scraped Html/page_2_1308.html
# HTML content saved to Scraped Html/page_2_1309.html
# HTML content saved to Scraped Html/page_2_1311.html
# HTML content saved to Scraped Html/page_2_1312.html
# HTML content saved to Scraped Html/page_2_1313.html
# HTML content saved to Scraped Html/page_2_1315.html
# HTML content saved to Scraped Html/page_2_1316.html
# HTML content saved to Scraped Html/page_2_1317.html
# HTML content saved to Scraped Html/page_2_1320.html
# HTML content saved to Scraped Html/page_2_1324.html
# HTML content saved to Scraped Html/page_2_1325.html
# HTML content saved to Scraped Html/page_2_1328.html
# HTML content saved to Scraped Html/page_2_1329.html
# HTML content saved to Scraped Html/page_2_133.html
# HTML content saved to Scraped Html/page_2_1331.html
# HTML content saved to Scraped Html/page_2_134.html
# HTML content saved to Scraped Html/page_2_135.html
# HTML content saved to Scraped Html/page_2_1367.html
# HTML content saved to Scraped Html/page_2_1368.html
# HTML content saved to Scraped Html/page_2_1370.html
# HTML content saved to Scraped Html/page_2_1371.html
# HTML content saved to Scraped Html/page_2_1372.html
# HTML content saved to Scraped Html/page_2_1374.html
# HTML content saved to Scraped Html/page_2_1375.html
# HTML content saved to Scraped Html/page_2_1376.html
# HTML content saved to Scraped Html/page_2_1377.html
# HTML content saved to Scraped Html/page_2_1379.html
# HTML content saved to Scraped Html/page_2_1380.html
# HTML content saved to Scraped Html/page_2_1382.html
# HTML content saved to Scraped Html/page_2_1386.html
# HTML content saved to Scraped Html/page_2_1387.html
# HTML content saved to Scraped Html/page_2_1388.html
# HTML content saved to Scraped Html/page_2_1390.html
# HTML content saved to Scraped Html/page_2_1391.html
# HTML content saved to Scraped Html/page_2_1392.html
# HTML content saved to Scraped Html/page_2_1395.html
# HTML content saved to Scraped Html/page_2_1396.html
# HTML content saved to Scraped Html/page_2_1397.html
# HTML content saved to Scraped Html/page_2_1398.html
# HTML content saved to Scraped Html/page_2_14.html
# HTML content saved to Scraped Html/page_2_1402.html
# HTML content saved to Scraped Html/page_2_1406.html
# HTML content saved to Scraped Html/page_2_1407.html
# HTML content saved to Scraped Html/page_2_1408.html
# HTML content saved to Scraped Html/page_2_1409.html
# HTML content saved to Scraped Html/page_2_141.html
# HTML content saved to Scraped Html/page_2_1410.html
# HTML content saved to Scraped Html/page_2_1413.html
# HTML content saved to Scraped Html/page_2_1414.html
# HTML content saved to Scraped Html/page_2_1415.html
# HTML content saved to Scraped Html/page_2_1417.html
# HTML content saved to Scraped Html/page_2_1419.html
# HTML content saved to Scraped Html/page_2_142.html
# HTML content saved to Scraped Html/page_2_1421.html
# HTML content saved to Scraped Html/page_2_1422.html
# HTML content saved to Scraped Html/page_2_1423.html
# HTML content saved to Scraped Html/page_2_1425.html
# HTML content saved to Scraped Html/page_2_1427.html
# HTML content saved to Scraped Html/page_2_1428.html
# HTML content saved to Scraped Html/page_2_1430.html
# HTML content saved to Scraped Html/page_2_1431.html
# HTML content saved to Scraped Html/page_2_1432.html
# HTML content saved to Scraped Html/page_2_1435.html
# HTML content saved to Scraped Html/page_2_1436.html
# HTML content saved to Scraped Html/page_2_1437.html
# HTML content saved to Scraped Html/page_2_1438.html
# HTML content saved to Scraped Html/page_2_1441.html
# HTML content saved to Scraped Html/page_2_1447.html
# HTML content saved to Scraped Html/page_2_1449.html
# HTML content saved to Scraped Html/page_2_145.html
# HTML content saved to Scraped Html/page_2_1454.html
# HTML content saved to Scraped Html/page_2_1456.html
# HTML content saved to Scraped Html/page_2_1459.html
# HTML content saved to Scraped Html/page_2_1461.html
# HTML content saved to Scraped Html/page_2_1466.html
# HTML content saved to Scraped Html/page_2_1468.html
# HTML content saved to Scraped Html/page_2_1469.html
# HTML content saved to Scraped Html/page_2_1473.html
# HTML content saved to Scraped Html/page_2_1474.html
# HTML content saved to Scraped Html/page_2_1476.html
# HTML content saved to Scraped Html/page_2_1477.html
# HTML content saved to Scraped Html/page_2_1478.html
# HTML content saved to Scraped Html/page_2_1479.html
# HTML content saved to Scraped Html/page_2_1480.html
# HTML content saved to Scraped Html/page_2_1483.html
# HTML content saved to Scraped Html/page_2_1484.html
# HTML content saved to Scraped Html/page_2_1485.html
# HTML content saved to Scraped Html/page_2_1486.html
# HTML content saved to Scraped Html/page_2_1487.html
# HTML content saved to Scraped Html/page_2_1488.html
# HTML content saved to Scraped Html/page_2_149.html
# HTML content saved to Scraped Html/page_2_1490.html
# HTML content saved to Scraped Html/page_2_1491.html
# HTML content saved to Scraped Html/page_2_1492.html
# HTML content saved to Scraped Html/page_2_1493.html
# HTML content saved to Scraped Html/page_2_1496.html
# HTML content saved to Scraped Html/page_2_1497.html
# HTML content saved to Scraped Html/page_2_1498.html
# HTML content saved to Scraped Html/page_2_1499.html
# HTML content saved to Scraped Html/page_2_15.html
# HTML content saved to Scraped Html/page_2_1500.html
# HTML content saved to Scraped Html/page_2_1501.html
# HTML content saved to Scraped Html/page_2_1502.html
# HTML content saved to Scraped Html/page_2_1509.html
# HTML content saved to Scraped Html/page_2_151.html
# HTML content saved to Scraped Html/page_2_1511.html
# HTML content saved to Scraped Html/page_2_1513.html
# HTML content saved to Scraped Html/page_2_1515.html
# HTML content saved to Scraped Html/page_2_1516.html
# HTML content saved to Scraped Html/page_2_1518.html
# HTML content saved to Scraped Html/page_2_1519.html
# HTML content saved to Scraped Html/page_2_152.html
# HTML content saved to Scraped Html/page_2_1522.html
# HTML content saved to Scraped Html/page_2_1525.html
# HTML content saved to Scraped Html/page_2_1527.html
# HTML content saved to Scraped Html/page_2_1528.html
# HTML content saved to Scraped Html/page_2_1529.html
# HTML content saved to Scraped Html/page_2_1530.html
# HTML content saved to Scraped Html/page_2_1532.html
# HTML content saved to Scraped Html/page_2_1533.html
# HTML content saved to Scraped Html/page_2_1534.html
# HTML content saved to Scraped Html/page_2_1535.html
# HTML content saved to Scraped Html/page_2_1536.html
# HTML content saved to Scraped Html/page_2_1537.html
# HTML content saved to Scraped Html/page_2_1539.html
# HTML content saved to Scraped Html/page_2_1542.html
# HTML content saved to Scraped Html/page_2_1543.html
# HTML content saved to Scraped Html/page_2_1545.html
# HTML content saved to Scraped Html/page_2_1548.html
# HTML content saved to Scraped Html/page_2_155.html
# HTML content saved to Scraped Html/page_2_1553.html
# HTML content saved to Scraped Html/page_2_1554.html
# HTML content saved to Scraped Html/page_2_1556.html
# HTML content saved to Scraped Html/page_2_1558.html
# HTML content saved to Scraped Html/page_2_156.html
# HTML content saved to Scraped Html/page_2_1561.html
# HTML content saved to Scraped Html/page_2_1562.html
# HTML content saved to Scraped Html/page_2_1564.html
# HTML content saved to Scraped Html/page_2_157.html
# HTML content saved to Scraped Html/page_2_1570.html
# HTML content saved to Scraped Html/page_2_1572.html
# HTML content saved to Scraped Html/page_2_1574.html
# HTML content saved to Scraped Html/page_2_1577.html
# HTML content saved to Scraped Html/page_2_1578.html
# HTML content saved to Scraped Html/page_2_1579.html
# HTML content saved to Scraped Html/page_2_158.html
# HTML content saved to Scraped Html/page_2_1580.html
# HTML content saved to Scraped Html/page_2_1582.html
# HTML content saved to Scraped Html/page_2_1583.html
# HTML content saved to Scraped Html/page_2_1584.html
# HTML content saved to Scraped Html/page_2_1585.html
# HTML content saved to Scraped Html/page_2_1586.html
# HTML content saved to Scraped Html/page_2_1587.html
# HTML content saved to Scraped Html/page_2_1588.html
# HTML content saved to Scraped Html/page_2_1589.html
# HTML content saved to Scraped Html/page_2_1590.html
# HTML content saved to Scraped Html/page_2_1591.html
# HTML content saved to Scraped Html/page_2_1593.html
# HTML content saved to Scraped Html/page_2_1594.html
# HTML content saved to Scraped Html/page_2_1595.html
# HTML content saved to Scraped Html/page_2_1598.html
# HTML content saved to Scraped Html/page_2_16.html
# HTML content saved to Scraped Html/page_2_160.html
# HTML content saved to Scraped Html/page_2_1601.html
# HTML content saved to Scraped Html/page_2_1602.html
# HTML content saved to Scraped Html/page_2_1603.html
# HTML content saved to Scraped Html/page_2_1604.html
# HTML content saved to Scraped Html/page_2_1606.html
# HTML content saved to Scraped Html/page_2_1607.html
# HTML content saved to Scraped Html/page_2_1611.html
# HTML content saved to Scraped Html/page_2_1612.html
# HTML content saved to Scraped Html/page_2_1613.html
# HTML content saved to Scraped Html/page_2_1618.html
# HTML content saved to Scraped Html/page_2_162.html
# HTML content saved to Scraped Html/page_2_1621.html
# HTML content saved to Scraped Html/page_2_1623.html
# HTML content saved to Scraped Html/page_2_1624.html
# HTML content saved to Scraped Html/page_2_1625.html
# HTML content saved to Scraped Html/page_2_1627.html
# HTML content saved to Scraped Html/page_2_1628.html
# HTML content saved to Scraped Html/page_2_1629.html
# HTML content saved to Scraped Html/page_2_1631.html
# HTML content saved to Scraped Html/page_2_1632.html
# HTML content saved to Scraped Html/page_2_1633.html
# HTML content saved to Scraped Html/page_2_1635.html
# HTML content saved to Scraped Html/page_2_1636.html
# HTML content saved to Scraped Html/page_2_1637.html
# HTML content saved to Scraped Html/page_2_1638.html
# HTML content saved to Scraped Html/page_2_1639.html
# HTML content saved to Scraped Html/page_2_1640.html
# HTML content saved to Scraped Html/page_2_1641.html
# HTML content saved to Scraped Html/page_2_1642.html
# HTML content saved to Scraped Html/page_2_1644.html
# HTML content saved to Scraped Html/page_2_1646.html
# HTML content saved to Scraped Html/page_2_165.html
# HTML content saved to Scraped Html/page_2_1653.html
# HTML content saved to Scraped Html/page_2_1654.html
# HTML content saved to Scraped Html/page_2_1655.html
# HTML content saved to Scraped Html/page_2_1657.html
# HTML content saved to Scraped Html/page_2_1659.html
# HTML content saved to Scraped Html/page_2_166.html
# HTML content saved to Scraped Html/page_2_1660.html
# HTML content saved to Scraped Html/page_2_1661.html
# HTML content saved to Scraped Html/page_2_1662.html
# HTML content saved to Scraped Html/page_2_1663.html
# HTML content saved to Scraped Html/page_2_1667.html
# HTML content saved to Scraped Html/page_2_1669.html
# HTML content saved to Scraped Html/page_2_1671.html
# HTML content saved to Scraped Html/page_2_1673.html
# HTML content saved to Scraped Html/page_2_1676.html
# HTML content saved to Scraped Html/page_2_168.html
# HTML content saved to Scraped Html/page_2_1680.html
# HTML content saved to Scraped Html/page_2_174.html
# HTML content saved to Scraped Html/page_2_175.html
# HTML content saved to Scraped Html/page_2_176.html
# HTML content saved to Scraped Html/page_2_177.html
# HTML content saved to Scraped Html/page_2_178.html
# HTML content saved to Scraped Html/page_2_18.html
# HTML content saved to Scraped Html/page_2_181.html
# HTML content saved to Scraped Html/page_2_183.html
# HTML content saved to Scraped Html/page_2_184.html
# HTML content saved to Scraped Html/page_2_185.html
# HTML content saved to Scraped Html/page_2_188.html
# HTML content saved to Scraped Html/page_2_19.html
# HTML content saved to Scraped Html/page_2_196.html
# HTML content saved to Scraped Html/page_2_203.html
# HTML content saved to Scraped Html/page_2_204.html
# HTML content saved to Scraped Html/page_2_21.html
# HTML content saved to Scraped Html/page_2_210.html
# HTML content saved to Scraped Html/page_2_211.html
# HTML content saved to Scraped Html/page_2_214.html
# HTML content saved to Scraped Html/page_2_215.html
# HTML content saved to Scraped Html/page_2_218.html
# HTML content saved to Scraped Html/page_2_219.html
# HTML content saved to Scraped Html/page_2_22.html
# HTML content saved to Scraped Html/page_2_220.html
# HTML content saved to Scraped Html/page_2_221.html
# HTML content saved to Scraped Html/page_2_225.html
# HTML content saved to Scraped Html/page_2_227.html
# HTML content saved to Scraped Html/page_2_228.html
# HTML content saved to Scraped Html/page_2_23.html
# HTML content saved to Scraped Html/page_2_230.html
# HTML content saved to Scraped Html/page_2_232.html
# HTML content saved to Scraped Html/page_2_235.html
# HTML content saved to Scraped Html/page_2_245.html
# HTML content saved to Scraped Html/page_2_246.html
# HTML content saved to Scraped Html/page_2_247.html
# HTML content saved to Scraped Html/page_2_248.html
# HTML content saved to Scraped Html/page_2_249.html
# HTML content saved to Scraped Html/page_2_251.html
# HTML content saved to Scraped Html/page_2_254.html
# HTML content saved to Scraped Html/page_2_255.html
