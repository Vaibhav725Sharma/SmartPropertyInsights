# %%
import pandas as pd

# %%
# Access each file by its name as specified in the upload
df1 = pd.read_csv("property_listings.csv")
df2 = pd.read_csv("property_listings_1.csv")
df3 = pd.read_csv("property_listings_2.csv")

# Now df1, df2, and df3 contain data from your three datasets

# %%
df2
# Out:
#                                               Image_URL Featured Shortlisted  \
# 0     https://imagecdn.99acres.com/media1/21001/15/4...      NaN         Yes
# 1     https://imagecdn.99acres.com/media1/26187/16/5...      NaN         Yes
# 2     https://static.99acres.com/universalapp/img/no...       No          No
# 3     https://imagecdn.99acres.com/media1/26126/12/5...      NaN         Yes
# 4     https://imagecdn.99acres.com/media1/25775/15/5...      NaN         Yes
# ...                                                 ...      ...         ...
# 2880  https://static.99acres.com/universalapp/img/Sh...       No         Yes
# 2881  https://static.99acres.com/universalapp/img/Sh...       No         Yes
# 2882  https://static.99acres.com/universalapp/img/Sh...       No         Yes
# 2883  https://static.99acres.com/universalapp/img/Sh...       No         Yes
# 2884  https://static.99acres.com/universalapp/img/Sh...       No         Yes
#
# ...

# %%
# Load the CSV files into individual DataFrames
df2 = pd.read_csv("property_listings.csv")
df3 = pd.read_csv("property_listings_1.csv")
df4 = pd.read_csv("property_listings_2.csv")

# Concatenate the DataFrames
new_df = pd.concat([df1, df2, df3], ignore_index=True)

# Display the combined DataFrame
new_df
# Out:
#                                               Image_URL Featured Shortlisted  \
# 0     https://imagecdn.99acres.com/media1/21001/15/4...      NaN         Yes
# 1     https://imagecdn.99acres.com/media1/26187/16/5...      NaN         Yes
# 2     https://static.99acres.com/universalapp/img/no...       No          No
# 3     https://imagecdn.99acres.com/media1/26126/12/5...      NaN         Yes
# 4     https://imagecdn.99acres.com/media1/25775/15/5...      NaN         Yes
# ...                                                 ...      ...         ...
# 8693  https://static.99acres.com/universalapp/img/no...       No          No
# 8694  https://static.99acres.com/universalapp/img/Gr...      NaN         Yes
# 8695  https://static.99acres.com/universalapp/img/Gr...      NaN         Yes
# 8696  https://static.99acres.com/universalapp/img/Gr...      NaN         Yes
# 8697                           https://static.99acres.c      NaN         NaN
#
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8698 entries, 0 to 8697
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Image_URL          8696 non-null   object
#  1   Featured           7064 non-null   object
#  2   Shortlisted        8697 non-null   object
#  3   Location_Name      8697 non-null   object
#  4   Rating             3289 non-null   float64
#  5   Tags               8664 non-null   object
#  6   Property_Type      8697 non-null   object
#  7   Property_Link      8697 non-null   object
#  8   Price              8697 non-null   object
#  9   Price_per_sqft     1350 non-null   object
#  10  Possession_Status  1350 non-null   object
#  11  Highlights         547 non-null    object
#  12  Dealer_Name        8696 non-null   object
#  13  Dealer_Badge       527 non-null    object
#  14  View_Number        8695 non-null   object
#  15  Chat_Now           8695 non-null   object
# ...
